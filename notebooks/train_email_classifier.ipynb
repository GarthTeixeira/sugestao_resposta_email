# %% [markdown]
# ### Instalar dependências

# %%
# !pip install spacy scikit-learn nltk
# !python -m spacy download pt_core_news_sm
# !pip install pandas
# Out:
# Requirement already satisfied: spacy in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (3.8.7)
# Requirement already satisfied: scikit-learn in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (1.7.1)
# Requirement already satisfied: nltk in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (0.17.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: scipy>=1.8.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 27.4 MB/s  0:00:00 eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# Requirement already satisfied: pandas in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/garth/Projetos/autoUProject/my_env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ### Importar bibliotecas

# %%
import sys
import os

# Adiciona o diretório raiz do projeto ao sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

import pickle
import pandas as pd
from pathlib import Path

from api.scripts.emailLematizer import EmailLematizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.preprocessing import FunctionTransformer

# %% [markdown]
# ### Dados de exemplo

# %%
notebook_dir = Path().resolve()  # se estiver rodando de dentro da pasta do notebook

df = pd.read_csv(notebook_dir / "emails_produtivo_improdutivo.csv")
texts = df["email"].values
labels = df["label"].values

# %% [markdown]
# ### Separar treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.25, random_state=42)

# %% [markdown]
# ### Criar pipeline TF-IDF + Classificador

# %%
preprocessor = EmailLematizer()

pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(preprocessor=preprocessor.lemmatize_text)),
    ("clf", MultinomialNB())
])

# %% [markdown]
# ### Treinar modelo

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(preprocessor=<bound method EmailLematizer.lemmatize_text of <api.scripts.emailLematizer.EmailLematizer object at 0x7f9122e5a490>>)),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# ### Avaliar modelo

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#  improdutivo       1.00      1.00      1.00        24
#    produtivo       1.00      1.00      1.00        26
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# ### Salvar modelo em pickle

# %%
with open("../api/models/email_classifier_pt.pkl", "wb") as f:
    pickle.dump(pipeline, f)

print("Modelo salvo em 'email_classifier_pt.pkl'")
# Out:
# Modelo salvo em 'email_classifier_pt.pkl'
